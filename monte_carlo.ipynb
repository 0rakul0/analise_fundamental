# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.random.random([10000])
y = np.random.random([10000])

# %%
eix = np.linspace(0,1,100)
circ = np.sqrt(np.ones(100)-eix**2)

# %%
plt.plot(eix,circ, '-k', linewidth=2)

# %%
n=0
m=0

# %%
for i in range(5000):
    M=m+1
    if x[i]**2+y[i]**2<1:
        N=n+1
        plt.plot(x[i], y[i], 'ok')
    else:
        plt.plot(x[i], y[i], 'ok', alpha=0.1)

# %%
pi = 4*N/M
print(pi)
# Out:
# 4.0
